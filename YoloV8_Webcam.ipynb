# %%
from ultralytics import YOLO

# %%
import matplotlib.pyplot as plt
import cv2

# %%
model = YOLO('C:/Users/HP/YoloV8_Large/runs/detect/train7/weights/best.pt')

# %%
cap = cv2.VideoCapture(0)
# cap.set(3,640) # adjust width
# cap.set(4,480) # adjust height
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# %%
vid_cod = cv2.VideoWriter_fourcc(*'mp4v')
output = cv2.VideoWriter("cam_video.mp4", vid_cod, 30.0, (frame_width,frame_height))

# %%
while cap.isOpened():
    success, img = cap.read()
    if not success:
        break
    # Doing detections using YOLOv8 frame by frame
    #stream = True will use the generator and it is more efficient than normal
    results=model(img,save=True)
    print(results)
    cv2.waitKey(1)
    res_plotted = results[0].plot()
    cv2.imshow("result",res_plotted)
    output.write(res_plotted)
    if cv2.waitKey(1) & 0xFF==ord('q'): # quit when 'q' is pressed
        cap.release()
        break

cap.release()
output.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 Not_fall, 167.2ms
# Speed: 22.0ms preprocess, 167.2ms inference, 57.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 (no detections), 17.0ms
# Speed: 3.7ms preprocess, 17.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[52, 70, 53],
#         [52, 71, 49],
#         [51, 71, 44],
#         ...,
#         [28, 47, 34],
#         [39, 58, 43],
#         [42, 62, 46]],
#
#        [[50, 68, 50],
#         [50, 68, 48],
#         [50, 69, 47],
#         ...,
#         [32, 53, 40],
#         [39, 63, 47],
#         [36, 60, 44]],
#
#        [[51, 65, 43],
#         [49, 65, 43],
#         [48, 67, 44],
#         ...,
#         [39, 65, 52],
#         [34, 63, 46],
#         [29, 58, 42]],
#
#        ...,
#
#        [[ 3, 12, 12],
#         [ 3, 12, 12],
#         [ 3, 12, 12],
#         ...,
#         [13, 24, 23],
#         [17, 26, 26],
#         [16, 25, 24]],
#
#        [[ 3, 12, 12],
#         [ 2, 11, 10],
#         [ 3, 12, 12],
#         ...,
#         [15, 24, 23],
#         [15, 24, 23],
#         [16, 25, 24]],
#
#        [[ 3, 12, 12],
#         [ 3, 12, 12],
#         [ 3, 12, 12],
#         ...,
#         [12, 22, 21],
#         [15, 24, 23],
#         [15, 24, 23]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 21.9728946685791, 'inference': 167.20867156982422, 'postprocess': 57.767629623413086}]
# 0: 480x640 1 fall, 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[132, 124, 150],
#         [131, 127, 141],
#         [131, 131, 133],
#         ...,
#         [ 87, 134, 150],
#         [ 93, 140, 154],
#         [ 62, 109, 123]],
#
#        [[129, 126, 140],
#         [130, 129, 136],
#         [133, 133, 133],
#         ...,
#         [ 90, 135, 157],
#         [ 90, 136, 154],
#         [ 70, 116, 134]],
#
#        [[127, 127, 127],
#         [133, 133, 131],
#         [134, 135, 130],
#         ...,
#         [ 89, 134, 154],
#         [ 84, 131, 145],
#         [ 74, 121, 135]],
#
#        ...,
#
#        [[ 13,  38,  38],
#         [ 14,  36,  37],
#         [ 16,  36,  37],
#         ...,
#         [ 84,  48,  46],
#         [ 91,  55,  53],
#         [113,  77,  76]],
#
#        [[ 21,  37,  38],
#         [ 23,  36,  37],
#         [ 26,  35,  37],
#         ...,
#         [ 95,  57,  56],
#         [ 95,  54,  53],
#         [110,  69,  69]],
#
#        [[ 20,  36,  37],
#         [ 23,  36,  37],
#         [ 26,  35,  37],
#         ...,
#         [ 89,  53,  54],
#         [ 91,  55,  53],
#         [ 97,  61,  59]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 3.6950111389160156, 'inference': 16.988277435302734, 'postprocess': 1.1067390441894531}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[138, 141, 131],
#         [138, 140, 135],
#         [136, 136, 136],
#         ...,
#         [ 91, 141, 146],
#         [104, 147, 150],
#         [ 70, 113, 116]],
#
#        [[136, 138, 129],
#         [134, 138, 131],
#         [133, 139, 134],
#         ...,
#         [ 96, 139, 147],
#         [107, 145, 149],
#         [ 81, 120, 123]],
#
#        [[133, 136, 122],
#         [138, 141, 130],
#         [137, 139, 130],
#         ...,
#         [ 95, 134, 152],
#         [101, 137, 152],
#         [ 87, 123, 138]],
#
#        ...,
#
#        [[ 26,  42,  43],
#         [ 28,  40,  41],
#         [ 32,  41,  43],
#         ...,
#         [ 72,  40,  22],
#         [ 94,  62,  44],
#         [131,  99,  82]],
#
#        [[ 32,  41,  43],
#         [ 34,  41,  43],
#         [ 36,  41,  43],
#         ...,
#         [ 80,  50,  33],
#         [ 89,  59,  41],
#         [ 94,  64,  47]],
#
#        [[ 39,  39,  41],
#         [ 36,  38,  40],
#         [ 35,  39,  41],
#         ...,
#         [ 84,  54,  36],
#         [ 98,  68,  50],
#         [101,  71,  54]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 1.9817352294921875, 'inference': 15.270471572875977, 'postprocess': 4.082918167114258}]
# 0: 480x640 1 fall, 20.9ms
# Speed: 4.0ms preprocess, 20.9ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 1 fall, 18.4ms
# Speed: 2.1ms preprocess, 18.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[138, 143, 138],
#         [141, 145, 138],
#         [142, 144, 135],
#         ...,
#         [ 85, 136, 152],
#         [ 81, 136, 154],
#         [ 58, 113, 131]],
#
#        [[131, 142, 136],
#         [137, 143, 135],
#         [141, 143, 134],
#         ...,
#         [ 86, 139, 150],
#         [ 82, 139, 152],
#         [ 60, 116, 130]],
#
#        [[120, 137, 135],
#         [131, 145, 141],
#         [131, 142, 136],
#         ...,
#         [ 90, 135, 145],
#         [ 80, 128, 138],
#         [ 73, 121, 131]],
#
#        ...,
#
#        [[ 30,  38,  44],
#         [ 30,  40,  46],
#         [ 24,  37,  43],
#         ...,
#         [ 83,  58,  40],
#         [ 91,  66,  48],
#         [109,  83,  65]],
#
#        [[ 24,  32,  38],
#         [ 25,  35,  43],
#         [ 26,  37,  47],
#         ...,
#         [ 85,  61,  47],
#         [ 93,  66,  53],
#         [101,  74,  61]],
#
#        [[ 19,  31,  37],
#         [ 21,  33,  41],
#         [ 26,  37,  47],
#         ...,
#         [ 83,  57,  43],
#         [ 93,  66,  53],
#         [ 98,  72,  58]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 3.9856433868408203, 'inference': 20.897865295410156, 'postprocess': 4.565000534057617}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[121, 137, 138],
#         [124, 140, 139],
#         [126, 142, 141],
#         ...,
#         [ 91, 131, 152],
#         [ 94, 129, 148],
#         [ 78, 112, 132]],
#
#        [[120, 134, 133],
#         [126, 140, 139],
#         [126, 140, 139],
#         ...,
#         [ 92, 130, 149],
#         [ 93, 126, 141],
#         [ 73, 106, 121]],
#
#        [[108, 117, 116],
#         [124, 134, 133],
#         [128, 137, 136],
#         ...,
#         [ 99, 135, 152],
#         [ 93, 126, 141],
#         [ 82, 116, 131]],
#
#        ...,
#
#        [[ 20,  32,  38],
#         [ 21,  33,  39],
#         [ 20,  32,  38],
#         ...,
#         [ 88,  63,  43],
#         [ 97,  72,  54],
#         [124,  99,  80]],
#
#        [[ 18,  34,  33],
#         [ 16,  34,  33],
#         [ 13,  34,  33],
#         ...,
#         [ 85,  58,  38],
#         [ 98,  69,  47],
#         [110,  81,  58]],
#
#        [[ 18,  34,  33],
#         [ 16,  34,  33],
#         [ 13,  34,  33],
#         ...,
#         [ 82,  55,  34],
#         [ 94,  65,  43],
#         [106,  77,  55]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 2.1321773529052734, 'inference': 18.42808723449707, 'postprocess': 3.0045509338378906}]
# 0: 480x640 1 fall, 23.2ms
# Speed: 2.9ms preprocess, 23.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 2 falls, 19.1ms
# Speed: 2.5ms preprocess, 19.1ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[137, 137, 137],
#         [139, 139, 135],
#         [143, 143, 134],
#         ...,
#         [ 90, 137, 171],
#         [ 92, 134, 171],
#         [ 66, 108, 145]],
#
#        [[138, 140, 135],
#         [140, 141, 134],
#         [141, 143, 134],
#         ...,
#         [ 90, 134, 171],
#         [ 88, 134, 171],
#         [ 68, 114, 151]],
#
#        [[136, 137, 133],
#         [140, 141, 134],
#         [138, 141, 131],
#         ...,
#         [ 85, 133, 165],
#         [ 79, 131, 163],
#         [ 72, 124, 156]],
#
#        ...,
#
#        [[ 38,  38,  38],
#         [ 36,  39,  38],
#         [ 34,  39,  38],
#         ...,
#         [ 79,  54,  32],
#         [123,  96,  83],
#         [141, 115, 101]],
#
#        [[ 27,  41,  40],
#         [ 29,  41,  40],
#         [ 32,  42,  41],
#         ...,
#         [ 86,  56,  35],
#         [119,  89,  71],
#         [140, 110,  92]],
#
#        [[ 27,  41,  40],
#         [ 29,  41,  40],
#         [ 32,  42,  41],
#         ...,
#         [ 82,  53,  29],
#         [ 98,  69,  47],
#         [125,  96,  73]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 2.880096435546875, 'inference': 23.24509620666504, 'postprocess': 2.9354095458984375}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[144, 135, 127],
#         [147, 137, 129],
#         [148, 138, 130],
#         ...,
#         [109, 141, 168],
#         [ 94, 131, 157],
#         [ 66, 103, 129]],
#
#        [[139, 140, 127],
#         [137, 137, 126],
#         [139, 139, 130],
#         ...,
#         [105, 138, 169],
#         [ 95, 136, 167],
#         [ 73, 114, 144]],
#
#        [[134, 137, 123],
#         [138, 142, 128],
#         [136, 139, 125],
#         ...,
#         [ 97, 133, 165],
#         [ 94, 135, 165],
#         [ 85, 126, 156]],
#
#        ...,
#
#        [[ 23,  37,  36],
#         [ 24,  36,  35],
#         [ 25,  35,  34],
#         ...,
#         [ 91,  65,  42],
#         [107,  78,  56],
#         [132, 103,  80]],
#
#        [[ 26,  36,  35],
#         [ 27,  34,  34],
#         [ 29,  34,  34],
#         ...,
#         [ 92,  59,  39],
#         [ 92,  54,  37],
#         [103,  66,  49]],
#
#        [[ 26,  36,  35],
#         [ 27,  34,  34],
#         [ 28,  33,  33],
#         ...,
#         [ 93,  58,  41],
#         [ 95,  58,  41],
#         [111,  74,  57]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 2.547025680541992, 'inference': 19.069910049438477, 'postprocess': 5.664587020874023}]
# 0: 480x640 2 falls, 20.7ms
# Speed: 1.0ms preprocess, 20.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 1 fall, 18.4ms
# Speed: 1.8ms preprocess, 18.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[145, 130, 138],
#         [146, 134, 139],
#         [144, 137, 137],
#         ...,
#         [101, 126, 154],
#         [ 94, 119, 147],
#         [ 89, 115, 142]],
#
#        [[138, 130, 133],
#         [144, 136, 138],
#         [142, 136, 136],
#         ...,
#         [ 96, 127, 154],
#         [ 96, 127, 154],
#         [ 94, 125, 151]],
#
#        [[132, 125, 127],
#         [146, 139, 141],
#         [144, 137, 137],
#         ...,
#         [ 92, 130, 156],
#         [ 91, 129, 155],
#         [ 92, 130, 156]],
#
#        ...,
#
#        [[ 29,  33,  39],
#         [ 28,  32,  36],
#         [ 31,  35,  37],
#         ...,
#         [ 87,  56,  49],
#         [ 93,  64,  62],
#         [124,  95,  93]],
#
#        [[ 23,  35,  45],
#         [ 25,  36,  41],
#         [ 29,  38,  39],
#         ...,
#         [ 84,  57,  48],
#         [ 96,  68,  62],
#         [107,  79,  72]],
#
#        [[ 23,  35,  45],
#         [ 24,  36,  44],
#         [ 27,  39,  45],
#         ...,
#         [ 86,  58,  49],
#         [ 98,  70,  64],
#         [101,  73,  66]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 1.0013580322265625, 'inference': 20.677566528320312, 'postprocess': 3.0443668365478516}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[137, 141, 125],
#         [136, 142, 127],
#         [137, 144, 130],
#         ...,
#         [107, 135, 182],
#         [106, 133, 183],
#         [ 76, 103, 153]],
#
#        [[133, 141, 127],
#         [136, 142, 128],
#         [141, 144, 130],
#         ...,
#         [105, 133, 178],
#         [102, 130, 180],
#         [ 81, 109, 159]],
#
#        [[135, 138, 124],
#         [144, 148, 134],
#         [138, 142, 128],
#         ...,
#         [101, 131, 170],
#         [104, 133, 175],
#         [ 91, 120, 163]],
#
#        ...,
#
#        [[ 38,  37,  44],
#         [ 36,  37,  44],
#         [ 35,  38,  45],
#         ...,
#         [ 95,  57,  44],
#         [128,  90,  77],
#         [156, 117, 105]],
#
#        [[ 32,  34,  45],
#         [ 33,  36,  44],
#         [ 33,  36,  43],
#         ...,
#         [ 98,  60,  50],
#         [108,  69,  59],
#         [138,  99,  89]],
#
#        [[ 31,  34,  40],
#         [ 30,  35,  41],
#         [ 29,  36,  43],
#         ...,
#         [101,  62,  52],
#         [101,  62,  52],
#         [126,  88,  78]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 1.8382072448730469, 'inference': 18.370628356933594, 'postprocess': 2.9985904693603516}]
# 0: 480x640 2 falls, 19.4ms
# Speed: 2.0ms preprocess, 19.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 1 fall, 23.8ms
# Speed: 1.7ms preprocess, 23.8ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[119, 138, 147],
#         [132, 140, 151],
#         [141, 138, 150],
#         ...,
#         [103, 132, 136],
#         [101, 133, 132],
#         [ 84, 116, 116]],
#
#        [[124, 137, 149],
#         [132, 141, 150],
#         [135, 139, 145],
#         ...,
#         [100, 133, 143],
#         [ 94, 132, 136],
#         [ 80, 118, 122]],
#
#        [[106, 121, 126],
#         [127, 139, 142],
#         [130, 139, 140],
#         ...,
#         [100, 135, 156],
#         [ 96, 136, 151],
#         [ 81, 121, 135]],
#
#        ...,
#
#        [[ 36,  36,  38],
#         [ 37,  37,  38],
#         [ 36,  36,  36],
#         ...,
#         [ 91,  59,  49],
#         [111,  80,  67],
#         [138, 106,  93]],
#
#        [[ 37,  37,  39],
#         [ 35,  37,  38],
#         [ 32,  36,  36],
#         ...,
#         [ 84,  52,  39],
#         [ 88,  55,  42],
#         [114,  81,  68]],
#
#        [[ 33,  38,  37],
#         [ 34,  36,  37],
#         [ 35,  34,  37],
#         ...,
#         [ 85,  52,  39],
#         [ 85,  52,  39],
#         [106,  72,  60]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 1.9898414611816406, 'inference': 19.43826675415039, 'postprocess': 2.531290054321289}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[138, 141, 131],
#         [136, 140, 133],
#         [135, 141, 136],
#         ...,
#         [ 77, 131, 158],
#         [ 61, 125, 154],
#         [ 41, 106, 134]],
#
#        [[135, 142, 132],
#         [136, 141, 131],
#         [138, 141, 131],
#         ...,
#         [ 83, 131, 159],
#         [ 73, 126, 155],
#         [ 53, 106, 135]],
#
#        [[128, 130, 121],
#         [138, 140, 133],
#         [138, 140, 135],
#         ...,
#         [ 87, 132, 160],
#         [ 83, 131, 161],
#         [ 71, 119, 149]],
#
#        ...,
#
#        [[ 32,  35,  41],
#         [ 32,  35,  40],
#         [ 31,  35,  37],
#         ...,
#         [105,  82,  72],
#         [114,  91,  84],
#         [126, 102,  95]],
#
#        [[ 24,  32,  38],
#         [ 24,  32,  36],
#         [ 24,  33,  34],
#         ...,
#         [ 96,  71,  61],
#         [104,  76,  70],
#         [117,  89,  82]],
#
#        [[ 23,  31,  37],
#         [ 22,  30,  36],
#         [ 24,  32,  38],
#         ...,
#         [ 74,  48,  43],
#         [ 88,  58,  61],
#         [101,  71,  73]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 1.718759536743164, 'inference': 23.826122283935547, 'postprocess': 4.61578369140625}]
# 0: 480x640 1 fall, 15.8ms
# Speed: 1.0ms preprocess, 15.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 1 fall, 15.9ms
# Speed: 1.0ms preprocess, 15.9ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[138, 136, 147],
#         [137, 138, 147],
#         [138, 141, 147],
#         ...,
#         [104, 139, 149],
#         [108, 142, 153],
#         [ 85, 119, 129]],
#
#        [[136, 135, 142],
#         [140, 139, 143],
#         [140, 139, 141],
#         ...,
#         [102, 138, 148],
#         [102, 139, 149],
#         [ 81, 118, 128]],
#
#        [[128, 127, 130],
#         [143, 143, 145],
#         [138, 138, 140],
#         ...,
#         [102, 138, 151],
#         [100, 136, 151],
#         [ 85, 120, 135]],
#
#        ...,
#
#        [[ 18,  39,  37],
#         [ 19,  40,  39],
#         [ 19,  40,  40],
#         ...,
#         [ 82,  63,  46],
#         [114,  95,  81],
#         [155, 135, 121]],
#
#        [[ 14,  40,  37],
#         [ 16,  39,  38],
#         [ 20,  41,  41],
#         ...,
#         [ 88,  67,  51],
#         [ 96,  76,  57],
#         [122, 101,  83]],
#
#        [[ 13,  38,  38],
#         [ 16,  39,  38],
#         [ 19,  40,  38],
#         ...,
#         [ 79,  59,  36],
#         [ 85,  65,  42],
#         [100,  80,  57]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 1.0030269622802734, 'inference': 15.825033187866211, 'postprocess': 3.4928321838378906}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[137, 135, 135],
#         [137, 136, 131],
#         [139, 139, 130],
#         ...,
#         [ 97, 133, 150],
#         [ 75, 117, 124],
#         [ 68, 110, 117]],
#
#        [[135, 132, 133],
#         [135, 134, 129],
#         [139, 139, 130],
#         ...,
#         [102, 136, 154],
#         [ 90, 125, 140],
#         [ 76, 111, 126]],
#
#        [[130, 128, 128],
#         [141, 139, 135],
#         [139, 139, 130],
#         ...,
#         [103, 135, 156],
#         [102, 134, 154],
#         [ 88, 120, 140]],
#
#        ...,
#
#        [[ 34,  32,  39],
#         [ 35,  33,  40],
#         [ 36,  34,  41],
#         ...,
#         [ 85,  62,  54],
#         [103,  79,  77],
#         [140, 115, 113]],
#
#        [[ 32,  31,  38],
#         [ 32,  32,  36],
#         [ 35,  34,  37],
#         ...,
#         [ 67,  46,  37],
#         [ 95,  71,  69],
#         [117,  93,  91]],
#
#        [[ 31,  30,  37],
#         [ 32,  32,  36],
#         [ 35,  34,  37],
#         ...,
#         [ 65,  45,  36],
#         [101,  79,  77],
#         [112,  90,  87]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 1.0225772857666016, 'inference': 15.887975692749023, 'postprocess': 3.834247589111328}]
# 0: 480x640 1 fall, 55.8ms
# Speed: 3.0ms preprocess, 55.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 2 falls, 56.1ms
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[135, 137, 128],
#         [133, 140, 128],
#         [128, 140, 125],
#         ...,
#         [106, 135, 154],
#         [101, 129, 145],
#         [ 87, 115, 131]],
#
#        [[132, 139, 129],
#         [130, 139, 127],
#         [129, 141, 127],
#         ...,
#         [107, 136, 157],
#         [112, 140, 160],
#         [ 96, 123, 144]],
#
#        [[124, 131, 121],
#         [134, 144, 132],
#         [128, 140, 125],
#         ...,
#         [103, 135, 155],
#         [103, 135, 155],
#         [ 93, 125, 145]],
#
#        ...,
#
#        [[ 32,  34,  29],
#         [ 32,  34,  29],
#         [ 32,  34,  29],
#         ...,
#         [ 85,  62,  43],
#         [ 99,  78,  60],
#         [137, 117,  98]],
#
#        [[ 28,  34,  29],
#         [ 28,  35,  27],
#         [ 28,  35,  25],
#         ...,
#         [ 85,  59,  41],
#         [ 92,  60,  42],
#         [119,  86,  69]],
#
#        [[ 28,  34,  29],
#         [ 30,  35,  25],
#         [ 32,  36,  22],
#         ...,
#         [ 87,  58,  43],
#         [104,  73,  60],
#         [112,  81,  68]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 3.002166748046875, 'inference': 55.84144592285156, 'postprocess': 3.6334991455078125}]
# Speed: 2.6ms preprocess, 56.1ms inference, 12.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 1 fall, 55.7ms
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[119, 139, 144],
#         [130, 140, 143],
#         [141, 140, 143],
#         ...,
#         [ 88, 137, 156],
#         [ 83, 139, 156],
#         [ 59, 114, 132]],
#
#        [[122, 136, 146],
#         [129, 138, 143],
#         [134, 139, 139],
#         ...,
#         [ 88, 139, 159],
#         [ 85, 142, 160],
#         [ 59, 117, 134]],
#
#        [[115, 129, 139],
#         [129, 138, 143],
#         [134, 139, 139],
#         ...,
#         [ 82, 136, 156],
#         [ 74, 131, 151],
#         [ 63, 120, 140]],
#
#        ...,
#
#        [[ 29,  38,  37],
#         [ 32,  39,  38],
#         [ 34,  39,  38],
#         ...,
#         [ 87,  52,  48],
#         [107,  71,  70],
#         [150, 114, 113]],
#
#        [[ 24,  38,  39],
#         [ 29,  38,  39],
#         [ 35,  39,  41],
#         ...,
#         [ 88,  49,  41],
#         [ 96,  56,  51],
#         [131,  91,  86]],
#
#        [[ 23,  37,  38],
#         [ 27,  38,  39],
#         [ 30,  39,  40],
#         ...,
#         [ 87,  47,  42],
#         [ 89,  49,  44],
#         [111,  72,  66]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 2.6497840881347656, 'inference': 56.13112449645996, 'postprocess': 12.536287307739258}]
# Speed: 3.7ms preprocess, 55.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 2 falls, 56.3ms
# Speed: 1.9ms preprocess, 56.3ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[118, 138, 143],
#         [123, 139, 141],
#         [126, 140, 139],
#         ...,
#         [ 80, 134, 164],
#         [ 76, 130, 155],
#         [ 55, 109, 134]],
#
#        [[123, 136, 142],
#         [125, 138, 141],
#         [127, 140, 141],
#         ...,
#         [ 83, 131, 159],
#         [ 85, 138, 163],
#         [ 69, 123, 148]],
#
#        [[121, 135, 136],
#         [134, 145, 145],
#         [130, 139, 139],
#         ...,
#         [ 88, 127, 160],
#         [ 90, 132, 165],
#         [ 76, 118, 151]],
#
#        ...,
#
#        [[ 20,  36,  35],
#         [ 23,  36,  36],
#         [ 26,  35,  37],
#         ...,
#         [ 84,  52,  43],
#         [105,  72,  66],
#         [146, 113, 107]],
#
#        [[ 28,  32,  34],
#         [ 29,  34,  35],
#         [ 29,  34,  34],
#         ...,
#         [ 79,  45,  39],
#         [ 98,  63,  57],
#         [123,  88,  82]],
#
#        [[ 32,  32,  34],
#         [ 32,  32,  34],
#         [ 34,  33,  36],
#         ...,
#         [ 80,  48,  42],
#         [ 91,  58,  52],
#         [114,  82,  75]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 3.6592483520507812, 'inference': 55.660247802734375, 'postprocess': 3.0035972595214844}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[112, 138, 143],
#         [118, 140, 141],
#         [124, 140, 139],
#         ...,
#         [100, 137, 157],
#         [ 90, 129, 148],
#         [ 70, 109, 128]],
#
#        [[113, 138, 138],
#         [119, 139, 136],
#         [125, 140, 134],
#         ...,
#         [102, 137, 157],
#         [100, 134, 154],
#         [ 81, 116, 135]],
#
#        [[108, 134, 131],
#         [123, 143, 139],
#         [123, 139, 133],
#         ...,
#         [ 98, 131, 152],
#         [ 94, 129, 148],
#         [ 84, 118, 138]],
#
#        ...,
#
#        [[ 24,  33,  33],
#         [ 27,  34,  34],
#         [ 29,  34,  34],
#         ...,
#         [ 80,  47,  50],
#         [113,  83,  86],
#         [147, 117, 120]],
#
#        [[ 23,  32,  31],
#         [ 26,  33,  33],
#         [ 31,  35,  35],
#         ...,
#         [ 84,  44,  48],
#         [105,  64,  67],
#         [136,  94,  98]],
#
#        [[ 23,  32,  31],
#         [ 26,  33,  33],
#         [ 31,  35,  35],
#         ...,
#         [ 82,  43,  45],
#         [ 97,  56,  59],
#         [103,  61,  65]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 1.9066333770751953, 'inference': 56.278228759765625, 'postprocess': 7.302045822143555}]
# 0: 480x640 2 falls, 57.2ms
# Speed: 2.8ms preprocess, 57.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 2 falls, 56.7ms
# Speed: 3.0ms preprocess, 56.7ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[138, 138, 129],
#         [141, 143, 128],
#         [140, 144, 124],
#         ...,
#         [ 96, 137, 158],
#         [102, 140, 162],
#         [ 70, 109, 130]],
#
#        [[131, 134, 124],
#         [138, 141, 129],
#         [140, 143, 127],
#         ...,
#         [ 90, 135, 161],
#         [ 95, 137, 163],
#         [ 73, 115, 141]],
#
#        [[129, 132, 118],
#         [137, 141, 127],
#         [138, 142, 128],
#         ...,
#         [ 90, 136, 164],
#         [ 92, 135, 165],
#         [ 78, 121, 151]],
#
#        ...,
#
#        [[ 29,  38,  39],
#         [ 34,  39,  39],
#         [ 38,  38,  38],
#         ...,
#         [ 68,  46,  41],
#         [ 96,  72,  74],
#         [128, 105, 107]],
#
#        [[ 29,  38,  39],
#         [ 34,  41,  42],
#         [ 35,  40,  40],
#         ...,
#         [ 75,  56,  49],
#         [ 96,  80,  72],
#         [ 99,  83,  75]],
#
#        [[ 30,  39,  40],
#         [ 33,  40,  40],
#         [ 35,  40,  40],
#         ...,
#         [ 84,  65,  58],
#         [ 92,  76,  68],
#         [ 94,  77,  70]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 2.826213836669922, 'inference': 57.16967582702637, 'postprocess': 2.996683120727539}]
# Results saved to runs\detect\predict18
#
# 0: 480x640 1 fall, 56.3ms
# Speed: 3.4ms preprocess, 56.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[133, 138, 137],
#         [131, 140, 132],
#         [130, 143, 128],
#         ...,
#         [ 99, 124, 162],
#         [100, 129, 161],
#         [ 84, 113, 144]],
#
#        [[131, 135, 135],
#         [131, 136, 133],
#         [132, 138, 133],
#         ...,
#         [ 93, 125, 160],
#         [ 92, 129, 160],
#         [ 78, 115, 146]],
#
#        [[123, 133, 128],
#         [131, 137, 131],
#         [135, 136, 131],
#         ...,
#         [ 90, 126, 159],
#         [ 91, 127, 160],
#         [ 83, 119, 152]],
#
#        ...,
#
#        [[ 23,  33,  28],
#         [ 24,  34,  29],
#         [ 26,  37,  31],
#         ...,
#         [ 80,  58,  47],
#         [102,  79,  72],
#         [145, 122, 115]],
#
#        [[ 23,  33,  28],
#         [ 24,  34,  29],
#         [ 28,  38,  32],
#         ...,
#         [ 83,  56,  47],
#         [ 97,  69,  63],
#         [125,  97,  91]],
#
#        [[ 23,  33,  28],
#         [ 24,  34,  29],
#         [ 28,  38,  32],
#         ...,
#         [ 76,  49,  40],
#         [ 82,  54,  48],
#         [102,  74,  67]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 3.0045509338378906, 'inference': 56.74934387207031, 'postprocess': 6.150722503662109}]
# 0: 480x640 2 falls, 57.1ms
# Speed: 3.3ms preprocess, 57.1ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[129, 140, 130],
#         [129, 140, 130],
#         [130, 142, 131],
#         ...,
#         [115, 139, 144],
#         [108, 133, 133],
#         [ 85, 110, 110]],
#
#        [[124, 142, 131],
#         [124, 139, 129],
#         [129, 140, 130],
#         ...,
#         [111, 138, 150],
#         [107, 133, 142],
#         [ 93, 119, 128]],
#
#        [[104, 120, 109],
#         [118, 134, 123],
#         [126, 142, 131],
#         ...,
#         [103, 136, 152],
#         [105, 138, 153],
#         [ 98, 131, 146]],
#
#        ...,
#
#        [[ 22,  39,  37],
#         [ 23,  40,  38],
#         [ 22,  39,  37],
#         ...,
#         [ 80,  59,  43],
#         [113,  92,  73],
#         [151, 130, 112]],
#
#        [[  9,  37,  35],
#         [ 10,  37,  35],
#         [ 15,  41,  38],
#         ...,
#         [ 76,  48,  30],
#         [ 97,  67,  49],
#         [132, 102,  84]],
#
#        [[  8,  36,  34],
#         [ 10,  37,  35],
#         [ 16,  42,  40],
#         ...,
#         [ 74,  46,  30],
#         [ 89,  58,  44],
#         [110,  79,  65]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 3.383636474609375, 'inference': 56.344032287597656, 'postprocess': 4.000186920166016}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[130, 142, 131],
#         [130, 142, 130],
#         [132, 145, 130],
#         ...,
#         [104, 138, 170],
#         [ 94, 125, 159],
#         [ 84, 115, 149]],
#
#        [[128, 139, 129],
#         [132, 141, 131],
#         [134, 141, 131],
#         ...,
#         [100, 134, 165],
#         [ 94, 126, 157],
#         [ 84, 115, 147]],
#
#        [[126, 133, 123],
#         [134, 138, 131],
#         [142, 143, 138],
#         ...,
#         [ 96, 130, 159],
#         [ 94, 131, 157],
#         [ 97, 134, 161]],
#
#        ...,
#
#        [[ 30,  36,  49],
#         [ 29,  36,  45],
#         [ 26,  34,  40],
#         ...,
#         [ 91,  51,  40],
#         [108,  69,  59],
#         [151, 112, 102]],
#
#        [[ 19,  33,  43],
#         [ 21,  34,  42],
#         [ 23,  36,  41],
#         ...,
#         [ 97,  55,  49],
#         [106,  61,  60],
#         [124,  78,  78]],
#
#        [[ 19,  33,  43],
#         [ 21,  34,  44],
#         [ 24,  36,  46],
#         ...,
#         [ 94,  51,  48],
#         [ 99,  54,  53],
#         [112,  67,  66]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 3.298044204711914, 'inference': 57.10196495056152, 'postprocess': 6.013393402099609}]
# 0: 480x640 1 fall, 57.1ms
# Speed: 2.5ms preprocess, 57.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[135, 135, 126],
#         [141, 139, 130],
#         [145, 140, 131],
#         ...,
#         [ 97, 126, 157],
#         [ 94, 126, 157],
#         [ 83, 114, 146]],
#
#        [[135, 135, 126],
#         [138, 138, 129],
#         [139, 139, 130],
#         ...,
#         [100, 127, 158],
#         [ 89, 119, 150],
#         [ 80, 109, 141]],
#
#        [[132, 132, 123],
#         [138, 139, 130],
#         [133, 135, 126],
#         ...,
#         [103, 131, 158],
#         [ 91, 121, 148],
#         [ 80, 111, 137]],
#
#        ...,
#
#        [[ 25,  41,  40],
#         [ 25,  40,  38],
#         [ 27,  41,  40],
#         ...,
#         [101,  72,  53],
#         [125,  96,  72],
#         [143, 115,  90]],
#
#        [[ 19,  35,  34],
#         [ 20,  36,  35],
#         [ 23,  40,  38],
#         ...,
#         [ 85,  51,  29],
#         [108,  72,  50],
#         [131,  95,  73]],
#
#        [[ 18,  34,  33],
#         [ 19,  35,  34],
#         [ 23,  40,  38],
#         ...,
#         [ 71,  37,  15],
#         [ 90,  54,  33],
#         [107,  71,  49]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 2.4776458740234375, 'inference': 57.09958076477051, 'postprocess': 3.1952857971191406}]
# 0: 480x640 2 falls, 57.2ms
# Speed: 3.5ms preprocess, 57.2ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 1 fall, 56.7ms
# Speed: 3.2ms preprocess, 56.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[136, 136, 138],
#         [136, 136, 137],
#         [137, 137, 137],
#         ...,
#         [ 92, 133, 162],
#         [ 93, 135, 161],
#         [ 70, 112, 137]],
#
#        [[136, 136, 138],
#         [135, 135, 134],
#         [136, 137, 133],
#         ...,
#         [ 89, 132, 162],
#         [ 91, 134, 164],
#         [ 76, 119, 149]],
#
#        [[128, 128, 128],
#         [131, 133, 128],
#         [136, 138, 129],
#         ...,
#         [ 89, 131, 159],
#         [ 89, 130, 161],
#         [ 85, 126, 156]],
#
#        ...,
#
#        [[ 40,  35,  27],
#         [ 40,  35,  27],
#         [ 41,  36,  28],
#         ...,
#         [ 79,  50,  35],
#         [121,  94,  81],
#         [154, 128, 114]],
#
#        [[ 35,  34,  25],
#         [ 37,  34,  25],
#         [ 40,  35,  27],
#         ...,
#         [ 87,  58,  43],
#         [110,  79,  65],
#         [121,  90,  77]],
#
#        [[ 35,  36,  22],
#         [ 37,  35,  22],
#         [ 40,  36,  23],
#         ...,
#         [ 82,  54,  38],
#         [ 99,  68,  55],
#         [112,  81,  68]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 3.5431385040283203, 'inference': 57.17825889587402, 'postprocess': 4.528045654296875}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[133, 143, 121],
#         [136, 142, 123],
#         [141, 142, 126],
#         ...,
#         [100, 139, 151],
#         [ 96, 136, 151],
#         [ 73, 113, 127]],
#
#        [[135, 145, 124],
#         [135, 142, 124],
#         [137, 141, 127],
#         ...,
#         [106, 141, 158],
#         [100, 134, 154],
#         [ 78, 112, 132]],
#
#        [[121, 129, 115],
#         [136, 142, 128],
#         [135, 138, 124],
#         ...,
#         [102, 141, 158],
#         [103, 142, 161],
#         [ 89, 128, 147]],
#
#        ...,
#
#        [[ 32,  36,  36],
#         [ 36,  39,  38],
#         [ 37,  37,  37],
#         ...,
#         [ 86,  57,  53],
#         [110,  81,  79],
#         [146, 117, 115]],
#
#        [[ 24,  33,  34],
#         [ 26,  33,  33],
#         [ 29,  34,  34],
#         ...,
#         [ 83,  55,  50],
#         [107,  77,  76],
#         [130, 101,  99]],
#
#        [[ 23,  32,  33],
#         [ 23,  32,  33],
#         [ 24,  33,  34],
#         ...,
#         [ 78,  52,  45],
#         [ 90,  62,  56],
#         [103,  75,  68]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 3.1843185424804688, 'inference': 56.7166805267334, 'postprocess': 3.143787384033203}]
# 0: 480x640 1 fall, 59.4ms
# Speed: 4.6ms preprocess, 59.4ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 2 falls, 56.1ms
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[145, 138, 111],
#         [146, 139, 113],
#         [151, 143, 119],
#         ...,
#         [102, 128, 155],
#         [101, 124, 147],
#         [ 89, 111, 134]],
#
#        [[141, 135, 111],
#         [141, 137, 115],
#         [145, 143, 122],
#         ...,
#         [ 99, 124, 156],
#         [103, 123, 155],
#         [ 97, 117, 149]],
#
#        [[135, 129, 105],
#         [137, 135, 112],
#         [135, 137, 117],
#         ...,
#         [ 97, 124, 156],
#         [ 95, 120, 151],
#         [ 95, 120, 151]],
#
#        ...,
#
#        [[ 28,  33,  33],
#         [ 28,  33,  33],
#         [ 28,  33,  33],
#         ...,
#         [ 91,  60,  46],
#         [110,  80,  62],
#         [149, 119, 101]],
#
#        [[ 21,  30,  29],
#         [ 22,  32,  28],
#         [ 24,  34,  29],
#         ...,
#         [ 87,  58,  34],
#         [104,  73,  48],
#         [134, 103,  79]],
#
#        [[ 21,  30,  29],
#         [ 21,  30,  27],
#         [ 24,  34,  29],
#         ...,
#         [ 85,  55,  33],
#         [ 87,  56,  34],
#         [109,  78,  56]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 4.579067230224609, 'inference': 59.37314033508301, 'postprocess': 5.344390869140625}]
# Speed: 2.9ms preprocess, 56.1ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[127, 141, 140],
#         [128, 143, 143],
#         [127, 143, 144],
#         ...,
#         [ 90, 136, 158],
#         [ 97, 146, 171],
#         [ 56, 105, 130]],
#
#        [[126, 140, 139],
#         [129, 141, 140],
#         [132, 142, 141],
#         ...,
#         [ 88, 135, 158],
#         [ 90, 139, 164],
#         [ 64, 113, 139]],
#
#        [[130, 139, 139],
#         [132, 142, 141],
#         [132, 142, 141],
#         ...,
#         [ 86, 130, 150],
#         [ 86, 131, 152],
#         [ 79, 125, 145]],
#
#        ...,
#
#        [[ 10,  36,  36],
#         [ 18,  41,  40],
#         [ 16,  37,  35],
#         ...,
#         [ 75,  39,  28],
#         [115,  81,  71],
#         [148, 114, 103]],
#
#        [[ 13,  37,  41],
#         [ 13,  37,  41],
#         [ 14,  38,  43],
#         ...,
#         [ 85,  46,  35],
#         [112,  74,  64],
#         [131,  92,  82]],
#
#        [[ 12,  36,  40],
#         [ 13,  34,  39],
#         [ 17,  36,  41],
#         ...,
#         [ 90,  52,  41],
#         [104,  66,  56],
#         [111,  73,  63]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 2.9485225677490234, 'inference': 56.07461929321289, 'postprocess': 5.600214004516602}]
# 0: 480x640 2 falls, 60.5ms
# Speed: 3.1ms preprocess, 60.5ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 1 fall, 57.2ms
# Speed: 2.3ms preprocess, 57.2ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[121, 141, 125],
#         [122, 142, 128],
#         [128, 147, 136],
#         ...,
#         [104, 128, 153],
#         [103, 130, 152],
#         [ 80, 107, 129]],
#
#        [[122, 142, 127],
#         [125, 142, 131],
#         [127, 142, 136],
#         ...,
#         [107, 130, 155],
#         [108, 134, 157],
#         [ 94, 120, 143]],
#
#        [[119, 137, 127],
#         [127, 142, 131],
#         [129, 140, 130],
#         ...,
#         [111, 133, 161],
#         [109, 135, 162],
#         [105, 131, 158]],
#
#        ...,
#
#        [[ 38,  38,  38],
#         [ 41,  41,  41],
#         [ 37,  37,  37],
#         ...,
#         [ 90,  54,  50],
#         [119,  83,  81],
#         [157, 121, 120]],
#
#        [[ 29,  34,  34],
#         [ 30,  33,  31],
#         [ 32,  34,  29],
#         ...,
#         [ 80,  44,  33],
#         [ 94,  55,  45],
#         [119,  81,  71]],
#
#        [[ 32,  33,  33],
#         [ 30,  33,  31],
#         [ 28,  34,  29],
#         ...,
#         [ 82,  44,  33],
#         [ 95,  56,  46],
#         [114,  75,  65]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 3.066539764404297, 'inference': 60.4710578918457, 'postprocess': 4.438638687133789}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[136, 137, 133],
#         [137, 137, 134],
#         [138, 136, 136],
#         ...,
#         [ 87, 141, 152],
#         [ 79, 136, 145],
#         [ 50, 107, 115]],
#
#        [[135, 137, 128],
#         [135, 137, 130],
#         [135, 136, 131],
#         ...,
#         [ 92, 139, 151],
#         [ 90, 138, 147],
#         [ 67, 116, 125]],
#
#        [[134, 136, 127],
#         [135, 137, 130],
#         [135, 136, 131],
#         ...,
#         [ 85, 136, 152],
#         [ 88, 139, 153],
#         [ 78, 130, 143]],
#
#        ...,
#
#        [[ 20,  34,  33],
#         [ 24,  33,  33],
#         [ 28,  33,  33],
#         ...,
#         [ 96,  62,  49],
#         [133, 102,  89],
#         [156, 125, 112]],
#
#        [[ 12,  34,  28],
#         [ 17,  35,  31],
#         [ 23,  37,  36],
#         ...,
#         [ 88,  47,  36],
#         [ 96,  58,  46],
#         [137,  99,  86]],
#
#        [[ 13,  36,  29],
#         [ 16,  35,  31],
#         [ 21,  38,  36],
#         ...,
#         [ 84,  41,  30],
#         [ 89,  46,  34],
#         [120,  77,  65]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 2.295255661010742, 'inference': 57.16300010681152, 'postprocess': 3.5817623138427734}]
# 0: 480x640 (no detections), 56.8ms
# Speed: 2.3ms preprocess, 56.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 1 fall, 56.5ms
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[130, 139, 139],
#         [130, 139, 139],
#         [130, 139, 139],
#         ...,
#         [ 86, 134, 143],
#         [ 87, 136, 143],
#         [ 72, 121, 128]],
#
#        [[130, 139, 139],
#         [130, 139, 139],
#         [130, 139, 139],
#         ...,
#         [ 92, 136, 146],
#         [ 88, 136, 146],
#         [ 73, 121, 131]],
#
#        [[123, 127, 129],
#         [134, 141, 142],
#         [130, 139, 139],
#         ...,
#         [ 91, 136, 146],
#         [ 89, 135, 145],
#         [ 82, 128, 138]],
#
#        ...,
#
#        [[ 37,  37,  37],
#         [ 35,  37,  37],
#         [ 32,  36,  36],
#         ...,
#         [ 84,  51,  40],
#         [125,  93,  82],
#         [161, 129, 118]],
#
#        [[ 37,  37,  37],
#         [ 37,  37,  38],
#         [ 37,  37,  39],
#         ...,
#         [ 77,  49,  37],
#         [ 94,  72,  60],
#         [110,  88,  77]],
#
#        [[ 37,  37,  39],
#         [ 37,  37,  38],
#         [ 37,  37,  37],
#         ...,
#         [ 71,  46,  34],
#         [ 90,  67,  56],
#         [ 93,  71,  59]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 2.321481704711914, 'inference': 56.77151679992676, 'postprocess': 1.0042190551757812}]
# Speed: 2.4ms preprocess, 56.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 2 falls, 56.5ms
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[134, 139, 139],
#         [136, 139, 137],
#         [138, 140, 135],
#         ...,
#         [ 99, 136, 156],
#         [102, 137, 156],
#         [ 83, 117, 137]],
#
#        [[135, 136, 131],
#         [136, 138, 131],
#         [136, 138, 129],
#         ...,
#         [ 96, 135, 154],
#         [ 98, 137, 156],
#         [ 81, 120, 139]],
#
#        [[122, 120, 120],
#         [131, 131, 129],
#         [135, 136, 131],
#         ...,
#         [ 94, 133, 150],
#         [ 94, 134, 148],
#         [ 84, 124, 139]],
#
#        ...,
#
#        [[ 37,  37,  39],
#         [ 37,  37,  38],
#         [ 37,  37,  37],
#         ...,
#         [ 83,  50,  37],
#         [129,  98,  85],
#         [162, 131, 118]],
#
#        [[ 35,  37,  48],
#         [ 36,  37,  43],
#         [ 37,  37,  37],
#         ...,
#         [ 81,  43,  31],
#         [101,  62,  52],
#         [139, 101,  91]],
#
#        [[ 34,  37,  44],
#         [ 34,  37,  44],
#         [ 33,  36,  43],
#         ...,
#         [ 86,  47,  37],
#         [ 93,  54,  44],
#         [119,  81,  71]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 2.359151840209961, 'inference': 56.534767150878906, 'postprocess': 2.8192996978759766}]
# Speed: 2.6ms preprocess, 56.5ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 1 fall, 55.8ms
# ...
# Results saved to runs\detect\predict18
#
# 0: 480x640 (no detections), 28.1ms
# Speed: 1.2ms preprocess, 28.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 (no detections), 24.8ms
# Speed: 2.8ms preprocess, 24.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[153, 138, 124],
#         [151, 138, 126],
#         [151, 139, 131],
#         ...,
#         [106, 132, 171],
#         [ 99, 130, 164],
#         [ 72, 103, 137]],
#
#        [[155, 141, 126],
#         [152, 141, 127],
#         [148, 139, 127],
#         ...,
#         [ 97, 136, 167],
#         [ 94, 135, 165],
#         [ 72, 113, 143]],
#
#        [[133, 125, 110],
#         [143, 138, 123],
#         [142, 139, 125],
#         ...,
#         [ 93, 138, 166],
#         [ 90, 139, 164],
#         [ 73, 122, 147]],
#
#        ...,
#
#        [[ 28,  36,  38],
#         [ 30,  36,  38],
#         [ 31,  35,  37],
#         ...,
#         [ 48,  51,  80],
#         [ 48,  51,  80],
#         [ 53,  56,  85]],
#
#        [[ 26,  34,  40],
#         [ 26,  35,  38],
#         [ 28,  37,  36],
#         ...,
#         [ 43,  47,  79],
#         [ 47,  49,  83],
#         [ 50,  51,  85]],
#
#        [[ 24,  33,  34],
#         [ 25,  34,  37],
#         [ 26,  34,  40],
#         ...,
#         [ 41,  45,  77],
#         [ 42,  47,  83],
#         [ 44,  50,  86]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 2.3550987243652344, 'inference': 25.025367736816406, 'postprocess': 1.0204315185546875}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[143, 144, 130],
#         [141, 142, 131],
#         [138, 141, 131],
#         ...,
#         [115, 134, 163],
#         [109, 129, 152],
#         [ 92, 112, 135]],
#
#        [[140, 143, 129],
#         [138, 142, 127],
#         [138, 142, 126],
#         ...,
#         [111, 129, 163],
#         [109, 127, 160],
#         [ 92, 110, 142]],
#
#        [[136, 139, 125],
#         [141, 143, 132],
#         [138, 141, 131],
#         ...,
#         [109, 132, 171],
#         [104, 127, 166],
#         [ 93, 116, 154]],
#
#        ...,
#
#        [[ 14,  40,  37],
#         [ 19,  40,  41],
#         [ 21,  36,  41],
#         ...,
#         [ 40,  47,  74],
#         [ 42,  49,  78],
#         [ 42,  49,  78]],
#
#        [[ 16,  37,  35],
#         [ 18,  36,  38],
#         [ 20,  35,  40],
#         ...,
#         [ 39,  48,  77],
#         [ 41,  50,  79],
#         [ 39,  48,  77]],
#
#        [[ 13,  34,  33],
#         [ 13,  34,  35],
#         [ 13,  33,  38],
#         ...,
#         [ 36,  47,  72],
#         [ 43,  53,  81],
#         [ 42,  52,  80]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 1.2259483337402344, 'inference': 28.074026107788086, 'postprocess': 1.0352134704589844}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[116, 144, 132],
#         [118, 144, 132],
#         [122, 145, 134],
#         ...,
#         [105, 136, 160],
#         [109, 142, 158],
#         [ 88, 121, 137]],
#
#        [[115, 143, 131],
#         [116, 142, 130],
#         [119, 143, 131],
#         ...,
#         [104, 134, 166],
#         [106, 138, 169],
#         [ 87, 119, 150]],
#
#        [[115, 138, 127],
#         [118, 138, 130],
#         [120, 138, 131],
#         ...,
#         [102, 134, 167],
#         [ 94, 125, 159],
#         [ 83, 114, 147]],
#
#        ...,
#
#        [[ 34,  36,  27],
#         [ 36,  38,  31],
#         [ 37,  38,  34],
#         ...,
#         [ 34,  42,  78],
#         [ 36,  44,  80],
#         [ 35,  43,  79]],
#
#        [[ 32,  35,  25],
#         [ 35,  36,  30],
#         [ 38,  39,  35],
#         ...,
#         [ 36,  44,  80],
#         [ 35,  43,  79],
#         [ 35,  43,  79]],
#
#        [[ 32,  35,  25],
#         [ 35,  36,  31],
#         [ 38,  38,  38],
#         ...,
#         [ 33,  43,  79],
#         [ 31,  43,  79],
#         [ 31,  43,  79]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 2.810955047607422, 'inference': 24.785518646240234, 'postprocess': 1.0037422180175781}]
# 0: 480x640 1 fall, 25.2ms
# Speed: 2.3ms preprocess, 25.2ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 (no detections), 25.6ms
# Speed: 1.8ms preprocess, 25.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 1 fall, 24.7ms
# Speed: 1.8ms preprocess, 24.7ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[126, 139, 140],
#         [126, 140, 139],
#         [126, 140, 139],
#         ...,
#         [ 92, 130, 144],
#         [104, 134, 143],
#         [ 93, 123, 131]],
#
#        [[126, 139, 140],
#         [125, 139, 136],
#         [125, 140, 134],
#         ...,
#         [ 88, 131, 149],
#         [ 91, 132, 142],
#         [ 78, 120, 129]],
#
#        [[123, 137, 136],
#         [130, 145, 140],
#         [122, 138, 128],
#         ...,
#         [ 85, 132, 152],
#         [ 89, 134, 148],
#         [ 78, 122, 137]],
#
#        ...,
#
#        [[ 39,  38,  45],
#         [ 37,  35,  44],
#         [ 37,  35,  46],
#         ...,
#         [ 30,  45,  89],
#         [ 34,  49,  93],
#         [ 37,  52,  96]],
#
#        [[ 35,  33,  40],
#         [ 35,  33,  40],
#         [ 34,  32,  39],
#         ...,
#         [ 32,  40,  84],
#         [ 40,  47,  87],
#         [ 42,  49,  89]],
#
#        [[ 32,  31,  38],
#         [ 32,  31,  38],
#         [ 34,  32,  39],
#         ...,
#         [ 30,  40,  86],
#         [ 32,  42,  87],
#         [ 34,  45,  89]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 2.262592315673828, 'inference': 25.218963623046875, 'postprocess': 3.567934036254883}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[145, 145, 145],
#         [146, 146, 144],
#         [145, 144, 140],
#         ...,
#         [ 95, 142, 151],
#         [ 90, 143, 150],
#         [ 63, 116, 123]],
#
#        [[145, 147, 142],
#         [144, 145, 141],
#         [141, 142, 137],
#         ...,
#         [ 90, 139, 146],
#         [ 86, 140, 146],
#         [ 70, 124, 130]],
#
#        [[128, 138, 133],
#         [141, 147, 142],
#         [140, 141, 136],
#         ...,
#         [ 86, 137, 144],
#         [ 83, 136, 143],
#         [ 81, 134, 140]],
#
#        ...,
#
#        [[ 31,  29,  55],
#         [ 32,  32,  51],
#         [ 34,  36,  49],
#         ...,
#         [ 35,  54,  86],
#         [ 29,  49,  82],
#         [ 23,  43,  76]],
#
#        [[ 31,  29,  55],
#         [ 34,  31,  53],
#         [ 38,  34,  53],
#         ...,
#         [ 35,  52,  80],
#         [ 32,  53,  80],
#         [ 28,  49,  77]],
#
#        [[ 31,  29,  55],
#         [ 33,  30,  52],
#         [ 37,  33,  52],
#         ...,
#         [ 30,  50,  78],
#         [ 32,  53,  80],
#         [ 30,  51,  79]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 1.7971992492675781, 'inference': 25.608539581298828, 'postprocess': 1.0042190551757812}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[133, 142, 125],
#         [136, 142, 129],
#         [140, 142, 132],
#         ...,
#         [102, 134, 145],
#         [104, 134, 143],
#         [ 76, 106, 115]],
#
#        [[136, 140, 124],
#         [135, 138, 123],
#         [138, 142, 128],
#         ...,
#         [105, 137, 154],
#         [102, 136, 147],
#         [ 79, 113, 124]],
#
#        [[128, 132, 115],
#         [134, 137, 122],
#         [137, 141, 127],
#         ...,
#         [106, 137, 159],
#         [105, 137, 156],
#         [ 93, 125, 145]],
#
#        ...,
#
#        [[ 34,  33,  36],
#         [ 32,  32,  33],
#         [ 32,  33,  33],
#         ...,
#         [ 37,  48,  72],
#         [ 36,  47,  71],
#         [ 36,  47,  71]],
#
#        [[ 32,  28,  47],
#         [ 32,  30,  42],
#         [ 32,  31,  38],
#         ...,
#         [ 36,  46,  73],
#         [ 35,  46,  70],
#         [ 35,  46,  70]],
#
#        [[ 32,  28,  47],
#         [ 32,  29,  45],
#         [ 32,  29,  43],
#         ...,
#         [ 36,  46,  75],
#         [ 35,  45,  73],
#         [ 35,  45,  73]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 1.7707347869873047, 'inference': 24.67060089111328, 'postprocess': 3.4003257751464844}]
# 0: 480x640 (no detections), 25.3ms
# Speed: 1.6ms preprocess, 25.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 (no detections), 25.2ms
# Speed: 1.9ms preprocess, 25.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
#
# 0: 480x640 (no detections), 24.7ms
# Speed: 2.0ms preprocess, 24.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[141, 142, 128],
#         [139, 142, 128],
#         [140, 143, 129],
#         ...,
#         [ 89, 132, 154],
#         [ 94, 137, 158],
#         [ 81, 124, 145]],
#
#        [[138, 142, 128],
#         [138, 142, 128],
#         [138, 142, 128],
#         ...,
#         [ 92, 133, 157],
#         [ 99, 137, 163],
#         [ 85, 123, 149]],
#
#        [[143, 147, 131],
#         [145, 149, 133],
#         [138, 142, 126],
#         ...,
#         [ 91, 132, 154],
#         [ 96, 134, 156],
#         [ 84, 123, 144]],
#
#        ...,
#
#        [[ 39,  32,  33],
#         [ 41,  32,  33],
#         [ 43,  32,  33],
#         ...,
#         [ 23,  45,  72],
#         [ 23,  45,  72],
#         [ 22,  43,  71]],
#
#        [[ 39,  32,  33],
#         [ 37,  32,  33],
#         [ 35,  32,  33],
#         ...,
#         [ 29,  49,  77],
#         [ 28,  49,  77],
#         [ 20,  41,  69]],
#
#        [[ 39,  32,  33],
#         [ 37,  32,  33],
#         [ 35,  32,  33],
#         ...,
#         [ 29,  49,  77],
#         [ 34,  52,  80],
#         [ 34,  52,  80]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 1.6064643859863281, 'inference': 25.259017944335938, 'postprocess': 0.9984970092773438}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[138, 148, 108],
#         [137, 149, 110],
#         [137, 150, 112],
#         ...,
#         [109, 136, 156],
#         [105, 138, 153],
#         [ 81, 114, 130]],
#
#        [[138, 147, 110],
#         [138, 146, 112],
#         [138, 146, 113],
#         ...,
#         [107, 139, 159],
#         [106, 138, 158],
#         [ 87, 119, 139]],
#
#        [[134, 142, 105],
#         [138, 146, 114],
#         [138, 144, 119],
#         ...,
#         [104, 137, 156],
#         [101, 136, 155],
#         [ 90, 124, 144]],
#
#        ...,
#
#        [[ 32,  33,  47],
#         [ 33,  35,  47],
#         [ 32,  34,  45],
#         ...,
#         [ 30,  51,  92],
#         [ 30,  57, 100],
#         [ 31,  58, 101]],
#
#        [[ 32,  33,  47],
#         [ 31,  32,  46],
#         [ 32,  33,  47],
#         ...,
#         [ 25,  48,  89],
#         [ 28,  54,  98],
#         [ 30,  57, 100]],
#
#        [[ 32,  33,  47],
#         [ 32,  33,  47],
#         [ 32,  33,  47],
#         ...,
#         [ 26,  48,  91],
#         [ 26,  48,  94],
#         [ 27,  49,  95]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 1.9474029541015625, 'inference': 25.163650512695312, 'postprocess': 1.0597705841064453}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[129, 143, 142],
#         [131, 143, 142],
#         [133, 143, 142],
#         ...,
#         [ 91, 137, 154],
#         [ 94, 141, 155],
#         [ 76, 123, 137]],
#
#        [[128, 142, 141],
#         [129, 141, 140],
#         [131, 141, 140],
#         ...,
#         [ 94, 138, 156],
#         [ 96, 140, 159],
#         [ 80, 124, 142]],
#
#        [[131, 141, 140],
#         [135, 144, 143],
#         [130, 139, 139],
#         ...,
#         [ 94, 133, 150],
#         [ 94, 134, 148],
#         [ 82, 122, 137]],
#
#        ...,
#
#        [[ 23,  37,  38],
#         [ 27,  38,  39],
#         [ 28,  36,  38],
#         ...,
#         [ 40,  50,  74],
#         [ 40,  50,  74],
#         [ 40,  50,  74]],
#
#        [[ 22,  38,  39],
#         [ 27,  39,  40],
#         [ 30,  39,  40],
#         ...,
#         [ 36,  49,  75],
#         [ 39,  48,  77],
#         [ 40,  49,  78]],
#
#        [[ 22,  38,  39],
#         [ 29,  39,  40],
#         [ 34,  38,  40],
#         ...,
#         [ 36,  49,  75],
#         [ 39,  48,  77],
#         [ 37,  47,  76]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 1.9958019256591797, 'inference': 24.732351303100586, 'postprocess': 1.0042190551757812}]
# 0: 480x640 (no detections), 24.6ms
# Speed: 2.1ms preprocess, 24.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict18
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'fall', 1: 'Not_fall', 2: 'Risky'}
# orig_img: array([[[126, 139, 140],
#         [127, 141, 141],
#         [128, 142, 141],
#         ...,
#         [ 96, 129, 159],
#         [ 98, 125, 164],
#         [ 80, 108, 146]],
#
#        [[124, 139, 140],
#         [127, 140, 138],
#         [131, 142, 136],
#         ...,
#         [ 95, 129, 157],
#         [ 92, 123, 157],
#         [ 77, 108, 142]],
#
#        [[123, 137, 136],
#         [132, 146, 144],
#         [125, 139, 137],
#         ...,
#         [ 95, 130, 154],
#         [ 95, 128, 155],
#         [ 86, 119, 145]],
#
#        ...,
#
#        [[ 34,  34,  34],
#         [ 32,  33,  33],
#         [ 32,  33,  33],
#         ...,
#         [ 44,  47,  72],
#         [ 48,  47,  72],
#         [ 49,  48,  73]],
#
#        [[ 31,  34,  40],
#         [ 31,  34,  38],
#         [ 31,  35,  37],
#         ...,
#         [ 40,  44,  69],
#         [ 45,  48,  73],
#         [ 45,  48,  73]],
#
#        [[ 31,  34,  40],
#         [ 31,  34,  38],
#         [ 31,  35,  37],
#         ...,
#         [ 44,  45,  69],
#         [ 49,  48,  73],
#         [ 49,  48,  73]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict18'
# speed: {'preprocess': 2.0623207092285156, 'inference': 24.60646629333496, 'postprocess': 2.1467208862304688}]
