# %%
from ultralytics import YOLO
import cv2

# %%
model = YOLO('C:/Users/HP/YoloV8_Large/runs/detect/train7/weights/best.pt')

# %%
source="https://www.youtube.com/watch?v=FXVfNxJ1dKw"

# %%
# %%HTML
# <div align="center">
# <iframe width="560" height="315" src="https://www.youtube.com/embed/FXVfNxJ1dKw" </iframe>
# </div>
# Out:
# <div align="center">
# <iframe width="560" height="315" src="https://www.youtube.com/embed/FXVfNxJ1dKw" </iframe>
# </div>

# %%
from ultralytics import YOLO
import cv2

# Load a model
model = YOLO('C:/Users/HP/YoloV8_Large/runs/detect/train7/weights/best.pt')  # pretrained YOLOv8n model

# Run batched inference on a list of images
results = model(source, stream=True)  # return a generator of Results objects

# Process results generator
for result in results:
#     boxes = result.boxes  # Boxes object for bbox outputs
#     masks = result.masks  # Masks object for segmentation masks outputs
#     keypoints = result.keypoints  # Keypoints object for pose outputs
      probs = result.probs
# Out:
# 1/1: https://www.youtube.com/watch?v=FXVfNxJ1dKw... Success  (1027 frames of shape 1280x720 at 25.00 FPS)
#
# 0: 384x640 (no detections), 76.8ms
# 0: 384x640 (no detections), 73.5ms
# 0: 384x640 1 Not_fall, 19.2ms
# 0: 384x640 1 Not_fall, 17.7ms
# 0: 384x640 1 Not_fall, 19.4ms
# 0: 384x640 1 Not_fall, 16.6ms
# 0: 384x640 1 Not_fall, 19.9ms
# 0: 384x640 1 Not_fall, 15.7ms
# 0: 384x640 1 Not_fall, 18.4ms
# 0: 384x640 1 Not_fall, 18.6ms
# 0: 384x640 1 fall, 3 Not_falls, 16.5ms
# 0: 384x640 1 fall, 3 Not_falls, 16.3ms
# 0: 384x640 1 fall, 3 Not_falls, 26.0ms
# 0: 384x640 1 fall, 3 Not_falls, 13.9ms
# 0: 384x640 1 fall, 3 Not_falls, 18.8ms
# 0: 384x640 1 fall, 3 Not_falls, 12.9ms
# 0: 384x640 1 fall, 3 Not_falls, 18.7ms
# 0: 384x640 1 fall, 3 Not_falls, 14.9ms
# 0: 384x640 1 fall, 3 Not_falls, 18.0ms
# 0: 384x640 1 fall, 3 Not_falls, 20.3ms
# 0: 384x640 1 fall, 3 Not_falls, 15.4ms
# 0: 384x640 1 fall, 3 Not_falls, 16.1ms
# 0: 384x640 1 fall, 3 Not_falls, 17.0ms
# ...
