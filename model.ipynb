# %%
from ultralytics import YOLO

# %%
# Load a model
#model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO()

# %%
# Use the model
results = model.train(data="data.yaml", epochs=50, workers=0, batch=2)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.0.125 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.124  Python-3.10.9 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...

# %%
# !yolo task=detect mode=val model='C:/Users/HP/Yolov8_Large/runs/detect/train7/weights/best.pt' data=data.yaml
# Out:
# Ultralytics YOLOv8.0.124  Python-3.10.9 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients
#
# val: Scanning C:\Users\HP\OneDrive\Desktop\data1\val\labels.cache... 989 images, 21 backgrounds, 0 corrupt: 100%|##########| 989/989 [00:00<?, ?it/s]
# val: Scanning C:\Users\HP\OneDrive\Desktop\data1\val\labels.cache... 989 images, 21 backgrounds, 0 corrupt: 100%|##########| 989/989 [00:00<?, ?it/s]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/62 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   2%|1         | 1/62 [00:00<00:38,  1.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   3%|3         | 2/62 [00:01<00:32,  1.84it/s]
# ...

# %%
# !yolo task=detect mode=predict model='C:/Users/HP/YoloV8_Large/runs/detect/train7/weights/best.pt' conf=0.25 source=test_images
# Out:
# Ultralytics YOLOv8.0.124  Python-3.10.9 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients
#
# image 1/94 C:\Users\HP\YoloV8_Large\test_images\NF001.jpg: 480x640 2 Not_falls, 85.8ms
# image 2/94 C:\Users\HP\YoloV8_Large\test_images\NF002.jpg: 448x640 11 Not_falls, 88.0ms
# image 3/94 C:\Users\HP\YoloV8_Large\test_images\NF003.jpg: 352x640 10 Not_falls, 68.3ms
# image 4/94 C:\Users\HP\YoloV8_Large\test_images\NF004.jpg: 448x640 2 Not_falls, 15.0ms
# image 5/94 C:\Users\HP\YoloV8_Large\test_images\NF005.jpg: 448x640 2 Not_falls, 13.5ms
# image 6/94 C:\Users\HP\YoloV8_Large\test_images\NF006.jpg: 448x640 6 Not_falls, 17.5ms
# image 7/94 C:\Users\HP\YoloV8_Large\test_images\NF007.jpg: 448x640 1 fall, 4 Not_falls, 1 Risky, 17.7ms
# image 8/94 C:\Users\HP\YoloV8_Large\test_images\NF008.jpg: 480x640 2 Not_falls, 1 Risky, 20.5ms
# image 9/94 C:\Users\HP\YoloV8_Large\test_images\NF009.jpg: 480x640 3 Riskys, 15.2ms
# ...
